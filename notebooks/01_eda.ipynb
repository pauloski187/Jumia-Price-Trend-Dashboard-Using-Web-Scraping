# %% [markdown]
# # 01 - Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

raw_path = 'data/raw/jumia product.csv'
try:
    df = pd.read_csv(raw_path)
except FileNotFoundError:
    df = pd.DataFrame()
df.head()
