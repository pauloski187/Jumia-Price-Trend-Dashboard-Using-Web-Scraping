# %% [markdown]
# # 03 - Modeling

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

processed_path = 'data/processed/jumia_product_processed.csv'

try:
    df = pd.read_csv(processed_path)
except FileNotFoundError:
    df = pd.DataFrame()

# Placeholder modeling scaffold
print('Rows:', len(df))
