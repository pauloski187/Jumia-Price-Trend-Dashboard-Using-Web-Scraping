# %% [markdown]
# # 02 - Feature Engineering

# %%
import pandas as pd

raw_path = 'data/raw/jumia product.csv'
processed_path = 'data/processed/jumia_product_processed.csv'

try:
    df = pd.read_csv(raw_path)
except FileNotFoundError:
    df = pd.DataFrame()

# Example placeholder for engineered features
features = pd.DataFrame()
features.head()
