# %% [markdown]
# Visualization Starter
#
# This notebook loads the processed dataset and creates a few sanity-check visualizations.
#
# Assumes you have already run `notebooks/01_eda.ipynb` and saved `data/processed/jumia_product_processed.csv`.

# %%
# Imports and data loading
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# Path to processed CSV (adjust if you run from a different working diretory)
processed_path = Path('../data/processed/jumia_product_processed.csv').resolve()
print(f'Loading: {processed_path}')
p = pd.read_csv(processed_path, parse_dates=['date_scraped'])
print(p.shape)
p.head(3)
# Out:
# Loading: /Users/paulolusola/PycharmProjects/Jumia Price Trend Dashboard Using Web Scraping/data/processed/jumia_product_processed.csv
# (4744, 11)
#               category                                         name_clean  \
# 0          Smartphones  Xiaomi Redmi A5 - 6. 88 4gb Ram/128gb Rom - Black
# 1  Musical Instruments  Wireless Lapel Lavalier Microphone ANDROID Pho...
# 2  Musical Instruments  3. 5mm Dual Wireless Lavalier Lapel Microphone...
#
#                                             name_raw  \
# 0  Xiaomi Redmi A5 - 6. 88 4gb Ram/128gb Rom - Black
# 1  Wireless Lapel Lavalier Microphone ANDROID Pho...
# 2  3. 5mm Dual Wireless Lavalier Lapel Microphone...
#
#                                                  url  current_price_ngn  \
# 0  https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-...             102000
# 1  https://www.jumia.com.ng/generic-wireless-lape...               4200
# 2  https://www.jumia.com.ng/generic-3.5mm-dual-wi...               8710
#
# ...
